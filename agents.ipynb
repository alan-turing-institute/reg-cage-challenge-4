# %%
from pprint import pprint
from CybORG import CybORG
from CybORG.Simulator.Scenarios import EnterpriseScenarioGenerator
from CybORG.Agents import SleepAgent, EnterpriseGreenAgent

# Initialise the environment
steps = 1000
sg = EnterpriseScenarioGenerator(blue_agent_class=SleepAgent, 
                                green_agent_class=EnterpriseGreenAgent, 
                                red_agent_class=SleepAgent,
                                steps=steps)
cyborg = CybORG(scenario_generator=sg, seed=1234)

# Perform one generic step of the episode
cyborg.step()

# Get the dictionary of actions performed during that step
action_list = cyborg.environment_controller.action

# Separate the actions out into their three groups for easy viewing
green_actions = {'Sleep': {}, 'GreenLocalWork': {}, 'GreenAccessService': {}}
for agent, action in action_list.items():
    if 'green' in agent:
        action_str = str(action[0]) 
        if 'Sleep' in action_str:
            green_actions['Sleep'][agent] = action
        if 'GreenLocalWork' in action_str:
            green_actions['GreenLocalWork'][agent] = action
        if 'GreenAccessService' in action_str:
            green_actions['GreenAccessService'][agent] = action

# Print the dictionary
pprint(green_actions)
# Out:
# {'GreenAccessService': {'green_agent_0': [GreenAccessService 10.0.250.251 52826],
#                         'green_agent_1': [GreenAccessService 10.0.250.250 52436],
#                         'green_agent_11': [GreenAccessService 10.0.252.254 57263],
#                         'green_agent_16': [GreenAccessService 10.0.96.254 54235],
#                         'green_agent_18': [GreenAccessService 10.0.96.254 53740],
#                         'green_agent_20': [GreenAccessService 10.0.96.254 54055],
#                         'green_agent_21': [GreenAccessService 10.0.96.254 53548],
#                         'green_agent_25': [GreenAccessService 10.0.43.251 56108],
#                         'green_agent_26': [GreenAccessService 10.0.43.252 51225],
#                         'green_agent_29': [GreenAccessService 10.0.43.252 50072],
#                         'green_agent_31': [GreenAccessService 10.0.233.252 49531],
#                         'green_agent_32': [GreenAccessService 10.0.233.253 50307],
#                         'green_agent_34': [GreenAccessService 10.0.233.251 55928],
#                         'green_agent_36': [GreenAccessService 10.0.233.254 58635],
#                         'green_agent_39': [GreenAccessService 10.0.233.252 49622],
#                         'green_agent_4': [GreenAccessService 10.0.249.254 53028],
#                         'green_agent_40': [GreenAccessService 10.0.26.254 51479],
#                         'green_agent_43': [GreenAccessService 10.0.26.254 57144],
#                         'green_agent_44': [GreenAccessService 10.0.26.254 58029],
#                         'green_agent_49': [GreenAccessService 10.0.67.251 52053],
#                         'green_agent_55': [GreenAccessService 10.0.67.252 51650],
#                         'green_agent_7': [GreenAccessService 10.0.249.254 58923],
#                         'green_agent_8': [GreenAccessService 10.0.252.254 51432]},
#  'GreenLocalWork': {'green_agent_10': [GreenLocalWork 10.0.252.242],
#                     'green_agent_12': [GreenLocalWork 10.0.252.186],
#                     'green_agent_17': [GreenLocalWork 10.0.96.218],
#                     'green_agent_2': [GreenLocalWork 10.0.250.200],
#                     'green_agent_22': [GreenLocalWork 10.0.96.219],
#                     'green_agent_28': [GreenLocalWork 10.0.43.143],
#                     'green_agent_37': [GreenLocalWork 10.0.233.92],
#                     'green_agent_38': [GreenLocalWork 10.0.233.98],
#                     'green_agent_41': [GreenLocalWork 10.0.26.57],
#                     'green_agent_46': [GreenLocalWork 10.0.26.157],
#                     'green_agent_50': [GreenLocalWork 10.0.67.139],
#                     'green_agent_51': [GreenLocalWork 10.0.67.127],
#                     'green_agent_52': [GreenLocalWork 10.0.67.200],
#                     'green_agent_6': [GreenLocalWork 10.0.249.50]},
#  'Sleep': {'green_agent_13': [Sleep],
#            'green_agent_14': [Sleep],
#            'green_agent_15': [Sleep],
#            'green_agent_19': [Sleep],
#            'green_agent_23': [Sleep],
#            'green_agent_24': [Sleep],
#            'green_agent_27': [Sleep],
#            'green_agent_3': [Sleep],
#            'green_agent_30': [Sleep],
#            'green_agent_33': [Sleep],
#            'green_agent_35': [Sleep],
#            'green_agent_42': [Sleep],
#            'green_agent_45': [Sleep],
#            'green_agent_47': [Sleep],
#            'green_agent_48': [Sleep],
#            'green_agent_5': [Sleep],
#            'green_agent_53': [Sleep],
#            'green_agent_54': [Sleep],
#            'green_agent_9': [Sleep]}}

# %%
from CybORG import CybORG
from CybORG.Simulator.Scenarios import EnterpriseScenarioGenerator
from CybORG.Agents import SleepAgent, FiniteStateRedAgent, RandomSelectRedAgent
from rich import print

# Initialise environment
steps = 1000
sg = EnterpriseScenarioGenerator(blue_agent_class=SleepAgent, 
                                green_agent_class=EnterpriseGreenAgent, 
                                red_agent_class=RandomSelectRedAgent,
                                steps=steps)
cyborg = CybORG(scenario_generator=sg, seed=1234)

# Record actions of red_agent_0
red_agent_0_actions = []
blue_agent_0_actions = []
green_agent_0_actions = []
for i in range(10):
    cyborg.step()
    step_actions = cyborg.environment_controller.action
    red_agent_0_actions.append("{}:{}".format(i,step_actions['red_agent_0']))
    # blue_agent_0_actions.append(step_actions['blue_agent_0'])
    # green_agent_0_actions.append(step_actions['green_agent_0'])

# Print red_agent_0's actions
print(red_agent_0_actions)
# print(blue_agent_0_actions)
# print(green_agent_0_actions)
# Out:
# ** Turn 0 for red_agent_0 **
# Action: Initial Observation
# Action Success: UNKNOWN
#
# ** Turn 1 for red_agent_0 **
# Action: ExploitRemoteService 10.0.43.13
# Action Success: IN_PROGRESS
#
#
# *** red_agent_0 attempts to withdraw ***
#
# ** Turn 2 for red_agent_0 **
# Action: Withdraw contractor_network_subnet_user_host_5
# Action Success: IN_PROGRESS
#
# ** Turn 3 for red_agent_0 **
# Action: ExploitRemoteService 10.0.43.13
# Action Success: IN_PROGRESS
#
# ** Turn 0 for red_agent_5 **
# Action: Initial Observation
# Action Success: UNKNOWN
#
# ** Turn 4 for red_agent_0 **
# Action: DegradeServices contractor_network_subnet_user_host_5
# Action Success: FALSE
#
# ** Turn 1 for red_agent_5 **
# Action: Sleep
# Action Success: UNKNOWN
#
# ** Turn 5 for red_agent_0 **
# Action: Impact contractor_network_subnet_user_host_5
# Action Success: IN_PROGRESS
#
# ** Turn 2 for red_agent_5 **
# Action: PrivilegeEscalate admin_network_subnet_user_host_4
# Action Success: IN_PROGRESS
#
# ** Turn 6 for red_agent_0 **
# Action: DiscoverDeception None
# Action Success: FALSE
#
# ** Turn 3 for red_agent_5 **
# Action: AggressiveServiceDiscovery 10.0.26.29
# Action Success: FALSE
#
# ** Turn 7 for red_agent_0 **
# Action: ExploitRemoteService 10.0.43.13
# Action Success: IN_PROGRESS
#
# ** Turn 4 for red_agent_5 **
# Action: StealthServiceDiscovery 10.0.67.127
# Action Success: IN_PROGRESS
#
# ** Turn 8 for red_agent_0 **
# Action: Sleep
# Action Success: IN_PROGRESS
#
# ** Turn 5 for red_agent_5 **
# Action: ExploitRemoteService 10.0.67.127
# Action Success: IN_PROGRESS
#
# ** Turn 9 for red_agent_0 **
# Action: Sleep
# Action Success: IN_PROGRESS
#
# ** Turn 6 for red_agent_5 **
# Action: DiscoverDeception None
# Action Success: TRUE
# [
#     '0:[Sleep]',
#     '1:[Sleep]',
#     '2:[Sleep]',
#     '3:[ExploitRemoteService 10.0.43.13]',
#     '4:[Sleep]',
#     '5:[Impact contractor_network_subnet_user_host_5]',
#     '6:[Sleep]',
#     '7:[Sleep]',
#     '8:[Sleep]',
#     '9:[ExploitRemoteService 10.0.43.13]'
# ]
